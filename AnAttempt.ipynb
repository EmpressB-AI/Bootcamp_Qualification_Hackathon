# %%
import catboost

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display
import seaborn as sns

# %matplotlib inline

from sklearn.preprocessing import LabelEncoder,StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold
from sklearn.metrics import accuracy_score, r2_score, mean_squared_error
from sklearn.linear_model import LinearRegression, LogisticRegression
from catboost import CatBoostClassifier
import warnings
warnings.filterwarnings('ignore')

from sklearn.metrics import log_loss, roc_auc_score

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier,AdaBoostRegressor
from sklearn.tree import DecisionTreeClassifier

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
sub = pd.read_csv('SampleSubmission.csv')

# %%
dict = {'charge':1, 'lending':0}
target_map = {'yes':1, 'no':0}
train['default_status'].replace(target_map, inplace=True)
train['form_field47'].replace(dict, inplace=True)
test['form_field47'].replace(dict, inplace=True)

# %%
features = train.select_dtypes(exclude=object).columns.drop(['default_status'])
for col in features:
    train[col].fillna(-999, inplace = True)
    test[col].fillna(-999, inplace = True)

# %%
X = train[features]
y = train['default_status']

# %%
def metric(y, pred):
    return roc_auc_score(y, pred, labels=[0,1])

# %%
n_skf = 10
kf = StratifiedKFold(n_skf)
seed = 2020
params = {'n_estimators':5000, 'learning_rate':0.01, 
          'objective':'CrossEntropy', 'eval_metric':'AUC', 
          'random_seed':seed, 'early_stopping_rounds':200, 'max_depth':9,
          'use_best_model':True,}

# %%
score_list = []
score=0
test_oofs = []
for i, (tr_idx, vr_idx) in enumerate(kf.split(X,y)):
    X_train, y_train = X.loc[tr_idx, features], y.loc[tr_idx]
    xval, yval = X.loc[vr_idx, features], y.loc[vr_idx]
    
    model = CatBoostClassifier(**params)
    model.fit(X_train, y_train, eval_set=[(xval, yval)], verbose=100)
    p = model.predict_proba(xval)[:, 1]
    
    sc = metric(yval, p)
    score_list.append(sc)
    score+= sc/n_skf
    
    pred = model.predict_proba(test[features])[:, 1]
    test_oofs.append(pred)
    print('Fold {} : {}'. format(i, sc))

print()
print()
print('Avg log :', score)
# Out:
# 0:	test: 0.7976080	best: 0.7976080 (0)	total: 258ms	remaining: 21m 31s
# 100:	test: 0.8212678	best: 0.8212678 (100)	total: 14.8s	remaining: 11m 56s
# 200:	test: 0.8242382	best: 0.8242382 (200)	total: 32.2s	remaining: 12m 49s
# 300:	test: 0.8262571	best: 0.8262571 (300)	total: 46.1s	remaining: 12m
# 400:	test: 0.8276066	best: 0.8276066 (400)	total: 59.8s	remaining: 11m 25s
# 500:	test: 0.8286078	best: 0.8286102 (499)	total: 1m 15s	remaining: 11m 16s
# 600:	test: 0.8292577	best: 0.8292937 (590)	total: 1m 28s	remaining: 10m 48s
# 700:	test: 0.8299353	best: 0.8299514 (699)	total: 1m 42s	remaining: 10m 30s
# 800:	test: 0.8306242	best: 0.8306618 (793)	total: 1m 56s	remaining: 10m 11s
# 900:	test: 0.8310521	best: 0.8310642 (898)	total: 2m 11s	remaining: 9m 57s
# 1000:	test: 0.8314917	best: 0.8315054 (999)	total: 2m 26s	remaining: 9m 46s
# 1100:	test: 0.8318205	best: 0.8318205 (1100)	total: 2m 39s	remaining: 9m 26s
# 1200:	test: 0.8321040	best: 0.8321057 (1198)	total: 2m 55s	remaining: 9m 16s
# 1300:	test: 0.8324662	best: 0.8324662 (1300)	total: 3m 9s	remaining: 8m 59s
# 1400:	test: 0.8326182	best: 0.8326532 (1394)	total: 3m 23s	remaining: 8m 42s
# 1500:	test: 0.8328541	best: 0.8328633 (1499)	total: 3m 36s	remaining: 8m 24s
# 1600:	test: 0.8328969	best: 0.8329966 (1543)	total: 3m 50s	remaining: 8m 8s
# 1700:	test: 0.8328339	best: 0.8330202 (1638)	total: 4m 3s	remaining: 7m 53s
# 1800:	test: 0.8327981	best: 0.8330202 (1638)	total: 4m 17s	remaining: 7m 37s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.8330202059
# bestIteration = 1638
#
# Shrink model to first 1639 iterations.
# Fold 0 : 0.8330202059034912
# 0:	test: 0.8088281	best: 0.8088281 (0)	total: 211ms	remaining: 17m 32s
# 100:	test: 0.8366549	best: 0.8366549 (100)	total: 13.7s	remaining: 11m 6s
# 200:	test: 0.8400953	best: 0.8400953 (200)	total: 27.7s	remaining: 11m
# 300:	test: 0.8423994	best: 0.8423994 (300)	total: 41.2s	remaining: 10m 42s
# 400:	test: 0.8435760	best: 0.8435760 (400)	total: 54.8s	remaining: 10m 27s
# 500:	test: 0.8448766	best: 0.8448766 (500)	total: 1m 8s	remaining: 10m 15s
# 600:	test: 0.8458635	best: 0.8458663 (597)	total: 1m 22s	remaining: 10m
# 700:	test: 0.8464793	best: 0.8464793 (700)	total: 1m 35s	remaining: 9m 45s
# 800:	test: 0.8469922	best: 0.8469922 (800)	total: 1m 48s	remaining: 9m 30s
# 900:	test: 0.8473558	best: 0.8473558 (900)	total: 2m 2s	remaining: 9m 15s
# 1000:	test: 0.8476754	best: 0.8477112 (996)	total: 2m 15s	remaining: 9m 1s
# 1100:	test: 0.8480048	best: 0.8480260 (1095)	total: 2m 29s	remaining: 8m 48s
# 1200:	test: 0.8481674	best: 0.8481709 (1199)	total: 2m 42s	remaining: 8m 35s
# 1300:	test: 0.8483641	best: 0.8483784 (1299)	total: 2m 56s	remaining: 8m 21s
# 1400:	test: 0.8484027	best: 0.8484046 (1369)	total: 3m 10s	remaining: 8m 8s
# 1500:	test: 0.8484110	best: 0.8484230 (1426)	total: 3m 23s	remaining: 7m 54s
# 1600:	test: 0.8484617	best: 0.8485698 (1586)	total: 3m 37s	remaining: 7m 41s
# 1700:	test: 0.8484087	best: 0.8485698 (1586)	total: 3m 50s	remaining: 7m 27s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.8485698157
# bestIteration = 1586
#
# Shrink model to first 1587 iterations.
# Fold 1 : 0.8485698156885897
# 0:	test: 0.8061688	best: 0.8061688 (0)	total: 176ms	remaining: 14m 42s
# 100:	test: 0.8303949	best: 0.8303949 (100)	total: 14.1s	remaining: 11m 25s
# 200:	test: 0.8342864	best: 0.8342864 (200)	total: 28s	remaining: 11m 9s
# 300:	test: 0.8363945	best: 0.8363945 (300)	total: 41.5s	remaining: 10m 47s
# 400:	test: 0.8376536	best: 0.8376536 (400)	total: 55s	remaining: 10m 30s
# 500:	test: 0.8387459	best: 0.8387459 (500)	total: 1m 8s	remaining: 10m 15s
# 600:	test: 0.8393372	best: 0.8393648 (598)	total: 1m 21s	remaining: 9m 59s
# 700:	test: 0.8400704	best: 0.8400704 (700)	total: 1m 35s	remaining: 9m 44s
# 800:	test: 0.8404213	best: 0.8404213 (800)	total: 1m 48s	remaining: 9m 30s
# 900:	test: 0.8405999	best: 0.8406099 (888)	total: 2m 2s	remaining: 9m 17s
# 1000:	test: 0.8408729	best: 0.8408732 (999)	total: 2m 16s	remaining: 9m 4s
# 1100:	test: 0.8411826	best: 0.8411830 (1098)	total: 2m 29s	remaining: 8m 50s
# 1200:	test: 0.8414214	best: 0.8414569 (1196)	total: 2m 43s	remaining: 8m 36s
# 1300:	test: 0.8415980	best: 0.8416494 (1296)	total: 2m 56s	remaining: 8m 22s
# 1400:	test: 0.8415485	best: 0.8416892 (1345)	total: 3m 10s	remaining: 8m 8s
# 1500:	test: 0.8416119	best: 0.8416892 (1345)	total: 3m 23s	remaining: 7m 55s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.8416892048
# bestIteration = 1345
#
# Shrink model to first 1346 iterations.
# Fold 2 : 0.8416892047701614
# 0:	test: 0.8007851	best: 0.8007851 (0)	total: 155ms	remaining: 12m 56s
# 100:	test: 0.8235133	best: 0.8235133 (100)	total: 14s	remaining: 11m 19s
# 200:	test: 0.8280855	best: 0.8280855 (200)	total: 27.6s	remaining: 10m 59s
# 300:	test: 0.8302281	best: 0.8302281 (300)	total: 41.1s	remaining: 10m 41s
# 400:	test: 0.8318550	best: 0.8318550 (400)	total: 54.6s	remaining: 10m 26s
# 500:	test: 0.8326620	best: 0.8326759 (498)	total: 1m 8s	remaining: 10m 10s
# 600:	test: 0.8334026	best: 0.8334026 (600)	total: 1m 21s	remaining: 9m 56s
# 700:	test: 0.8340735	best: 0.8340735 (700)	total: 1m 34s	remaining: 9m 42s
# 800:	test: 0.8343740	best: 0.8343878 (798)	total: 1m 48s	remaining: 9m 27s
# 900:	test: 0.8346768	best: 0.8346768 (900)	total: 2m 1s	remaining: 9m 13s
# 1000:	test: 0.8349517	best: 0.8349621 (984)	total: 2m 15s	remaining: 8m 59s
# 1100:	test: 0.8353160	best: 0.8353258 (1099)	total: 2m 28s	remaining: 8m 46s
# 1200:	test: 0.8356218	best: 0.8356291 (1192)	total: 2m 42s	remaining: 8m 33s
# 1300:	test: 0.8360066	best: 0.8360121 (1299)	total: 2m 55s	remaining: 8m 20s
# 1400:	test: 0.8362896	best: 0.8363503 (1363)	total: 3m 10s	remaining: 8m 8s
# 1500:	test: 0.8362891	best: 0.8363800 (1431)	total: 3m 24s	remaining: 7m 55s
# 1600:	test: 0.8365006	best: 0.8365102 (1589)	total: 3m 38s	remaining: 7m 43s
# 1700:	test: 0.8362472	best: 0.8365189 (1607)	total: 3m 52s	remaining: 7m 30s
# 1800:	test: 0.8361651	best: 0.8365189 (1607)	total: 4m 6s	remaining: 7m 17s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.8365188509
# bestIteration = 1607
#
# Shrink model to first 1608 iterations.
# Fold 3 : 0.8365188508576897
# 0:	test: 0.7985447	best: 0.7985447 (0)	total: 185ms	remaining: 15m 22s
# 100:	test: 0.8321749	best: 0.8321749 (100)	total: 14.2s	remaining: 11m 30s
# 200:	test: 0.8359113	best: 0.8359113 (200)	total: 28.3s	remaining: 11m 14s
# 300:	test: 0.8383834	best: 0.8383834 (300)	total: 42.2s	remaining: 10m 59s
# 400:	test: 0.8399225	best: 0.8399225 (400)	total: 56.2s	remaining: 10m 44s
# 500:	test: 0.8411406	best: 0.8411406 (500)	total: 1m 10s	remaining: 10m 30s
# 600:	test: 0.8421201	best: 0.8421265 (599)	total: 1m 24s	remaining: 10m 15s
# 700:	test: 0.8428823	best: 0.8428939 (698)	total: 1m 37s	remaining: 9m 58s
# 800:	test: 0.8434861	best: 0.8434861 (800)	total: 1m 51s	remaining: 9m 43s
# 900:	test: 0.8437279	best: 0.8437290 (898)	total: 2m 5s	remaining: 9m 28s
# 1000:	test: 0.8439263	best: 0.8439522 (986)	total: 2m 18s	remaining: 9m 14s
# 1100:	test: 0.8441120	best: 0.8441120 (1100)	total: 2m 32s	remaining: 9m
# 1200:	test: 0.8444318	best: 0.8444482 (1195)	total: 2m 46s	remaining: 8m 47s
# 1300:	test: 0.8446850	best: 0.8447054 (1298)	total: 3m	remaining: 8m 33s
# 1400:	test: 0.8448314	best: 0.8448618 (1396)	total: 3m 14s	remaining: 8m 19s
# 1500:	test: 0.8450106	best: 0.8450106 (1500)	total: 3m 28s	remaining: 8m 6s
# 1600:	test: 0.8449894	best: 0.8450487 (1527)	total: 3m 42s	remaining: 7m 51s
# 1700:	test: 0.8450317	best: 0.8450881 (1645)	total: 3m 55s	remaining: 7m 36s
# 1800:	test: 0.8448761	best: 0.8450881 (1645)	total: 4m 8s	remaining: 7m 21s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.8450880732
# bestIteration = 1645
#
# Shrink model to first 1646 iterations.
# Fold 4 : 0.8450880732340467
# 0:	test: 0.8058186	best: 0.8058186 (0)	total: 161ms	remaining: 13m 27s
# 100:	test: 0.8319561	best: 0.8319561 (100)	total: 14s	remaining: 11m 19s
# 200:	test: 0.8356386	best: 0.8356386 (200)	total: 27.7s	remaining: 11m 1s
# 300:	test: 0.8375223	best: 0.8375223 (300)	total: 41.2s	remaining: 10m 42s
# 400:	test: 0.8390073	best: 0.8390073 (400)	total: 54.6s	remaining: 10m 26s
# 500:	test: 0.8400677	best: 0.8400689 (498)	total: 1m 8s	remaining: 10m 12s
# 600:	test: 0.8408717	best: 0.8408717 (600)	total: 1m 21s	remaining: 9m 57s
# 700:	test: 0.8414101	best: 0.8414440 (690)	total: 1m 35s	remaining: 9m 43s
# 800:	test: 0.8419121	best: 0.8419205 (798)	total: 1m 48s	remaining: 9m 27s
# 900:	test: 0.8421222	best: 0.8421245 (896)	total: 2m 1s	remaining: 9m 13s
# 1000:	test: 0.8424018	best: 0.8424023 (999)	total: 2m 15s	remaining: 8m 59s
# 1100:	test: 0.8425322	best: 0.8425353 (1098)	total: 2m 28s	remaining: 8m 46s
# 1200:	test: 0.8426587	best: 0.8427104 (1183)	total: 2m 42s	remaining: 8m 32s
# 1300:	test: 0.8427401	best: 0.8427833 (1244)	total: 2m 55s	remaining: 8m 19s
# 1400:	test: 0.8428995	best: 0.8429200 (1389)	total: 3m 9s	remaining: 8m 5s
# 1500:	test: 0.8428199	best: 0.8429200 (1389)	total: 3m 22s	remaining: 7m 52s
# 1600:	test: 0.8429805	best: 0.8430190 (1566)	total: 3m 35s	remaining: 7m 38s
# 1700:	test: 0.8430147	best: 0.8430607 (1680)	total: 3m 49s	remaining: 7m 25s
# 1800:	test: 0.8428573	best: 0.8430607 (1680)	total: 4m 3s	remaining: 7m 11s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.8430607004
# bestIteration = 1680
#
# Shrink model to first 1681 iterations.
# Fold 5 : 0.8430607004255952
# 0:	test: 0.7896324	best: 0.7896324 (0)	total: 157ms	remaining: 13m 5s
# 100:	test: 0.8102809	best: 0.8102809 (100)	total: 14.5s	remaining: 11m 45s
# 200:	test: 0.8139432	best: 0.8139432 (200)	total: 28.1s	remaining: 11m 11s
# 300:	test: 0.8155020	best: 0.8155020 (300)	total: 41.6s	remaining: 10m 49s
# 400:	test: 0.8170070	best: 0.8170070 (400)	total: 55.1s	remaining: 10m 31s
# 500:	test: 0.8177234	best: 0.8177234 (500)	total: 1m 8s	remaining: 10m 18s
# 600:	test: 0.8184709	best: 0.8184766 (598)	total: 1m 22s	remaining: 10m 1s
# 700:	test: 0.8189398	best: 0.8189800 (690)	total: 1m 35s	remaining: 9m 46s
# 800:	test: 0.8193423	best: 0.8193444 (799)	total: 1m 49s	remaining: 9m 31s
# 900:	test: 0.8194220	best: 0.8194797 (828)	total: 2m 2s	remaining: 9m 17s
# 1000:	test: 0.8195792	best: 0.8195792 (1000)	total: 2m 16s	remaining: 9m 3s
# 1100:	test: 0.8197259	best: 0.8197710 (1083)	total: 2m 29s	remaining: 8m 50s
# 1200:	test: 0.8200315	best: 0.8200496 (1191)	total: 2m 43s	remaining: 8m 36s
# 1300:	test: 0.8203268	best: 0.8203353 (1296)	total: 2m 56s	remaining: 8m 22s
# 1400:	test: 0.8203966	best: 0.8204363 (1320)	total: 3m 10s	remaining: 8m 8s
# 1500:	test: 0.8202460	best: 0.8204363 (1320)	total: 3m 23s	remaining: 7m 55s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.8204362972
# bestIteration = 1320
#
# Shrink model to first 1321 iterations.
# Fold 6 : 0.8204362972381816
# 0:	test: 0.8079075	best: 0.8079075 (0)	total: 156ms	remaining: 13m
# 100:	test: 0.8283567	best: 0.8283567 (100)	total: 14.2s	remaining: 11m 29s
# 200:	test: 0.8338501	best: 0.8338501 (200)	total: 28s	remaining: 11m 8s
# 300:	test: 0.8363849	best: 0.8363849 (300)	total: 41.7s	remaining: 10m 51s
# 400:	test: 0.8382243	best: 0.8382272 (399)	total: 55.2s	remaining: 10m 33s
# 500:	test: 0.8393924	best: 0.8394102 (499)	total: 1m 8s	remaining: 10m 18s
# 600:	test: 0.8402899	best: 0.8402899 (600)	total: 1m 22s	remaining: 10m 2s
# 700:	test: 0.8406943	best: 0.8407010 (698)	total: 1m 36s	remaining: 9m 51s
# 800:	test: 0.8411224	best: 0.8411224 (800)	total: 1m 50s	remaining: 9m 41s
# 900:	test: 0.8414747	best: 0.8414966 (897)	total: 2m 5s	remaining: 9m 28s
# 1000:	test: 0.8417521	best: 0.8417621 (998)	total: 2m 19s	remaining: 9m 16s
# 1100:	test: 0.8420143	best: 0.8420143 (1100)	total: 2m 34s	remaining: 9m 8s
# 1200:	test: 0.8422465	best: 0.8422710 (1197)	total: 2m 50s	remaining: 9m
# 1300:	test: 0.8422110	best: 0.8422894 (1213)	total: 3m 6s	remaining: 8m 49s
# 1400:	test: 0.8423379	best: 0.8423379 (1400)	total: 3m 21s	remaining: 8m 36s
# 1500:	test: 0.8423849	best: 0.8424248 (1485)	total: 3m 34s	remaining: 8m 20s
# 1600:	test: 0.8424177	best: 0.8424248 (1485)	total: 3m 48s	remaining: 8m 5s
# 1700:	test: 0.8424635	best: 0.8425299 (1681)	total: 4m 2s	remaining: 7m 50s
# 1800:	test: 0.8424010	best: 0.8425801 (1723)	total: 4m 17s	remaining: 7m 37s
# 1900:	test: 0.8423805	best: 0.8425801 (1723)	total: 4m 33s	remaining: 7m 25s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.8425800784
# bestIteration = 1723
#
# Shrink model to first 1724 iterations.
# Fold 7 : 0.8425800783889715
# 0:	test: 0.8283618	best: 0.8283618 (0)	total: 206ms	remaining: 17m 7s
# 100:	test: 0.8494739	best: 0.8494739 (100)	total: 15.6s	remaining: 12m 35s
# 200:	test: 0.8521708	best: 0.8521708 (200)	total: 29.6s	remaining: 11m 47s
# 300:	test: 0.8538288	best: 0.8538288 (300)	total: 43.4s	remaining: 11m 17s
# 400:	test: 0.8549021	best: 0.8549487 (397)	total: 57.3s	remaining: 10m 56s
# 500:	test: 0.8558110	best: 0.8558110 (500)	total: 1m 11s	remaining: 10m 37s
# 600:	test: 0.8563028	best: 0.8563028 (600)	total: 1m 25s	remaining: 10m 24s
# 700:	test: 0.8565378	best: 0.8565417 (699)	total: 1m 39s	remaining: 10m 8s
# 800:	test: 0.8567957	best: 0.8567983 (799)	total: 1m 53s	remaining: 9m 57s
# 900:	test: 0.8568660	best: 0.8568884 (887)	total: 2m 8s	remaining: 9m 45s
# 1000:	test: 0.8567072	best: 0.8569289 (908)	total: 2m 22s	remaining: 9m 28s
# 1100:	test: 0.8567240	best: 0.8569289 (908)	total: 2m 36s	remaining: 9m 14s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.8569289217
# bestIteration = 908
#
# Shrink model to first 909 iterations.
# Fold 8 : 0.856928921724116
# 0:	test: 0.8105012	best: 0.8105012 (0)	total: 247ms	remaining: 20m 36s
# 100:	test: 0.8324447	best: 0.8324447 (100)	total: 14.6s	remaining: 11m 47s
# 200:	test: 0.8366419	best: 0.8366419 (200)	total: 28s	remaining: 11m 9s
# 300:	test: 0.8389777	best: 0.8389918 (299)	total: 41.5s	remaining: 10m 47s
# 400:	test: 0.8405047	best: 0.8405047 (400)	total: 54.8s	remaining: 10m 28s
# 500:	test: 0.8417024	best: 0.8417024 (500)	total: 1m 8s	remaining: 10m 11s
# 600:	test: 0.8427823	best: 0.8427826 (599)	total: 1m 21s	remaining: 9m 56s
# 700:	test: 0.8437234	best: 0.8437411 (696)	total: 1m 34s	remaining: 9m 41s
# 800:	test: 0.8444496	best: 0.8444496 (800)	total: 1m 47s	remaining: 9m 26s
# 900:	test: 0.8448636	best: 0.8448684 (893)	total: 2m 1s	remaining: 9m 11s
# 1000:	test: 0.8454459	best: 0.8454459 (1000)	total: 2m 14s	remaining: 8m 57s
# 1100:	test: 0.8459274	best: 0.8459596 (1095)	total: 2m 28s	remaining: 8m 44s
# 1200:	test: 0.8462951	best: 0.8463252 (1196)	total: 2m 41s	remaining: 8m 31s
# 1300:	test: 0.8466255	best: 0.8466369 (1297)	total: 2m 55s	remaining: 8m 18s
# 1400:	test: 0.8468184	best: 0.8468348 (1395)	total: 3m 8s	remaining: 8m 5s
# 1500:	test: 0.8469136	best: 0.8469136 (1500)	total: 3m 22s	remaining: 7m 52s
# 1600:	test: 0.8470689	best: 0.8470691 (1575)	total: 3m 36s	remaining: 7m 39s
# 1700:	test: 0.8472105	best: 0.8472279 (1694)	total: 3m 50s	remaining: 7m 26s
# 1800:	test: 0.8472317	best: 0.8472618 (1784)	total: 4m 3s	remaining: 7m 13s
# 1900:	test: 0.8472415	best: 0.8473303 (1822)	total: 4m 17s	remaining: 6m 59s
# 2000:	test: 0.8471650	best: 0.8473303 (1822)	total: 4m 31s	remaining: 6m 46s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.8473302722
# bestIteration = 1822
#
# Shrink model to first 1823 iterations.
# Fold 9 : 0.847330272154814
#
#
# Avg log : 0.8415222420385657

# %%
f'{n_skf} fold CV, score: {score}'
# Out:
# '10 fold CV, score: 0.8415222420385657'

# %%
oof_prediction = pd.DataFrame(test_oofs).T

# %%
oof_prediction.columns = ['fold' +str(i) for i in range(1, n_skf + 1)]

# %%
oof_prediction.head()
# Out:
#       fold1     fold2     fold3     fold4     fold5     fold6     fold7  \
# 0  0.281607  0.334704  0.318998  0.275459  0.289099  0.293496  0.284930
# 1  0.465998  0.397151  0.379288  0.433036  0.455497  0.385521  0.372149
# 2  0.343069  0.370492  0.386290  0.384291  0.385248  0.391442  0.374894
# 3  0.725817  0.751630  0.761503  0.755976  0.715240  0.788022  0.762193
# 4  0.149490  0.137024  0.148220  0.148248  0.171759  0.141220  0.149301
#
#       fold8     fold9    fold10
# 0  0.279107  0.279472  0.320711
# 1  0.378349  0.381009  0.409630
# 2  0.386745  0.329025  0.365185
# 3  0.738840  0.744081  0.743727
# 4  0.123363  0.163097  0.144054

# %%
sub['default_status'] = np.mean(test_oofs, axis=0)

# %%
sub.to_csv('tenth_submission.csv', index=False)
